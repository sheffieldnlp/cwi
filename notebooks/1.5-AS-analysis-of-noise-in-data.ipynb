# %%
"""
This notebook analyses noise in the datasets from inconsistencies in labelling 
between words and phrases.

"""

# imports
import glob
import pandas as pd
import numpy as np


# set up
languages = ["english", "spanish", "german", "french"]

filepaths = {}
for language in languages:
    filepaths[language] = glob.glob("../data/raw/"+language+"/*")
    
    
fieldnames = ['hit_id', 'sentence', 'start_offset', 'end_offset', 'target_word', 'native_annots', 
              'nonnative_annots', 'native_complex', 'nonnative_complex', 'gold_label', 'gold_prob']

target_cols = ['hit_id','sentence','start_offset', 'end_offset','target_word', 'gold_label']

df = pd.DataFrame()

# %%
# create dataframe
for language, paths in filepaths.items():
    for path in paths:
        source_df = pd.read_csv(path, sep='\t', header=None, names=fieldnames)
        target_df = source_df[target_cols]
        target_df.is_copy = False
        target_df['language'] = language
        df = df.append(target_df, ignore_index=True)
        
# clean df
df = df.dropna() 
df['n_words'] = df.apply(func= lambda row :  len( row['target_word'].split() ) , axis=1)  # number SWs in target word/phrase
df.head(10)
print(df.shape)
df.head(10)
# Out:
# C:\Users\Alison\Anaconda3\lib\site-packages\pandas\core\generic.py:4388: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   object.__getattribute__(self, name)
# C:\Users\Alison\Anaconda3\lib\site-packages\pandas\core\generic.py:4389: FutureWarning: Attribute 'is_copy' is deprecated and will be removed in a future version.
#   return object.__setattr__(self, name, value)
# (62640, 8)
#                            hit_id  \
# 0  3Z8UJEJOCZEG603II1EL4BE2PV593A
# 1  3Z8UJEJOCZEG603II1EL4BE2PV593A
# 2  3Z8UJEJOCZEG603II1EL4BE2PV593A
# 3  3Z8UJEJOCZEG603II1EL4BE2PV593A
# 4  3Z8UJEJOCZEG603II1EL4BE2PV593A
# 5  3Z8UJEJOCZEG603II1EL4BE2PV593A
# 6  3Z8UJEJOCZEG603II1EL4BE2PV593A
# 7  3Z8UJEJOCZEG603II1EL4BE2PV593A
# 8  3Z8UJEJOCZEG603II1EL4BE2PV593A
# 9  3Z8UJEJOCZEG603II1EL4BE2PV593A
#
#                                             sentence  start_offset  \
# 0  Syrian troops shelled a rebel-held town on Mon...             7
# 1  Syrian troops shelled a rebel-held town on Mon...             0
# 2  Syrian troops shelled a rebel-held town on Mon...            14
# 3  Syrian troops shelled a rebel-held town on Mon...            24
# 4  Syrian troops shelled a rebel-held town on Mon...            51
# 5  Syrian troops shelled a rebel-held town on Mon...            35
# 6  Syrian troops shelled a rebel-held town on Mon...            43
# 7  Syrian troops shelled a rebel-held town on Mon...            51
# 8  Syrian troops shelled a rebel-held town on Mon...            51
# 9  Syrian troops shelled a rebel-held town on Mon...            60
#
#    end_offset               target_word  gold_label language  n_words
# 0          13                    troops           0  english        1
# 1           6                    Syrian           0  english        1
# 2          21                   shelled           1  english        1
# 3          34                rebel-held           1  english        1
# 4          59                  sparking           1  english        1
# 5          39                      town           0  english        1
# 6          49                    Monday           0  english        1
# 7          67          sparking intense           1  english        2
# 8          75  sparking intense clashes           1  english        3
# 9          67                   intense           1  english        1

# %%
# get some initial counts
for language in languages:
    print(language, df.loc[df['language'] == language].shape[0], "total",
        ",", df.loc[(df['language'] == language) & (df['gold_label'] == 1)].shape[0], "complex")
    
print("\n")
for language in languages:
    print(language, 
          df.loc[(df['language'] == language) 
                 & (df['gold_label'] == 1)
                 & (df["n_words"] > 1)].shape[0], "complex MWP",
          df.loc[(df['language'] == language) 
                 & (df['gold_label'] == 0)
                 & (df["n_words"] > 1)].shape[0], "non-complex MWP")
# Out:
# english 34879 total , 14428 complex
# spanish 17605 total , 7015 complex
# german 7905 total , 3272 complex
# french 2251 total , 657 complex
#
#
# english 3750 complex MWP 982 non-complex MWP
# spanish 2309 complex MWP 0 non-complex MWP
# german 502 complex MWP 0 non-complex MWP
# french 242 complex MWP 0 non-complex MWP

# %%
# makes dictionary of counts of complex and NC MWPS, and MWPs w/ SWs of opposite label
def inconsistency_counter(languages):
    counters_dic ={}
    
    for language in languages: 
        MWP_counter = 0   # number multiword_phrases (MWPs)
        CMWP_counter = 0  # number of these phrases that are complex
        irregSW_counter = 0  # number MWPS with at least one inconsistently labelled SW
        allirregSW_counter = 0 # number MWPs with all SWs inconsistently labelled

        lang_dic = df.loc[(df['language'] == language)].to_dict()

        for row, value in lang_dic["n_words"].items():

            # count MWPS and complex MWPs
            if value > 1:  # if MWP
                MWP_counter += 1
                if lang_dic["gold_label"][row] == 1:
                    CMWP_counter += 1

                # define row attributes
                target_hit = lang_dic["hit_id"][row]
                target_sent = lang_dic["sentence"][row]
                target_MWP = lang_dic["target_word"][row]
                target_startoffset = lang_dic["start_offset"][row]
                target_endoffset = lang_dic["end_offset"][row]
                target_GL = lang_dic["gold_label"][row]
                target_irregSW_counter = 0
                target_SW_counter = 0
                
                # count how many SWs have the opposite label
                for row2, sent in lang_dic["sentence"].items():
                    if sent == target_sent:
                        if lang_dic["hit_id"][row2] == target_hit:
                            if lang_dic["start_offset"][row2]>= target_startoffset:  
                                if lang_dic["end_offset"][row2] <= target_endoffset:
                                    if len(target_MWP) > len(lang_dic["target_word"][row2]):
                                        target_SW_counter += 1
                                        if lang_dic["gold_label"][row2] != target_GL:
                                            target_irregSW_counter += 1

                # update irregular SW counters
                if target_irregSW_counter > 0:
                    irregSW_counter += 1
                    if target_SW_counter == target_irregSW_counter:
                        allirregSW_counter += 1

        # update dic
        counters_dic[language] = (CMWP_counter, MWP_counter - CMWP_counter, 
                                  irregSW_counter, allirregSW_counter)
    
    return counters_dic

counters_dic = inconsistency_counter(languages)

# %%
# make latex table of counters_dic
counters_df = pd.DataFrame(data=counters_dic).transpose()
counters_df.columns =["C MWP","NC MWP",'$\geq 1$ Irreg. SW', 'All irreg. SWs']
counters_df.loc['Total']= counters_df.sum()

print(counters_df.to_latex())
counters_df
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &  C MWP &  NC MWP &  \$\textbackslash geq 1\$ Irreg. SW &  All irreg. SWs \\
# \midrule
# english &   3750 &     982 &                3315 &             950 \\
# spanish &   2309 &       0 &                1747 &             760 \\
# german  &    502 &       0 &                 374 &             178 \\
# french  &    242 &       0 &                 192 &              82 \\
# Total   &   6803 &     982 &                5628 &            1970 \\
# \bottomrule
# \end{tabular}
#          C MWP  NC MWP  $\geq 1$ Irreg. SW  All irreg. SWs
# english   3750     982                3315             950
# spanish   2309       0                1747             760
# german     502       0                 374             178
# french     242       0                 192              82
# Total     6803     982                5628            1970

# %%
# for given language and min number of words in MWPs, prints MWPS and SWs and counts irreg. SWs
def MWP_SW_printer(language, min_length):  # language should be one of: english, spanish, german, french
        print(language, "MWPs with min number of words", min_length, ":\n-")
        
        MWP_counter = 0   # number multiword_phrases (MWPs)
        CMWP_counter = 0  # number of these phrases that are complex
        irregSW_counter = 0  # number MWPS with at least one inconsistently labelled SW
        allirregSW_counter = 0 # number MWPs with all SWs inconsistently labelled


        lang_dic = df.loc[(df['language'] == language)].to_dict()

        for row, value in lang_dic["n_words"].items():

            # count MWPS and complex MWPs
            if value >= min_length:  # if MWP with at least min_length words
                print("-"*20)
                MWP_counter += 1
                if lang_dic["gold_label"][row] == 1:
                    CMWP_counter += 1

                # define row attributes
                target_hit = lang_dic["hit_id"][row]
                target_sent = lang_dic["sentence"][row]
                target_MWP = lang_dic["target_word"][row]
                target_startoffset = lang_dic["start_offset"][row]
                target_endoffset = lang_dic["end_offset"][row]
                target_GL = lang_dic["gold_label"][row]
                target_irregSW_counter = 0
                target_SW_counter = 0
                print(target_MWP, target_GL)

                # count how many SWs have the opposite label
                for row2, sent in lang_dic["sentence"].items():
                    if sent == target_sent:
                        if lang_dic["hit_id"][row2] == target_hit:
                            if lang_dic["start_offset"][row2]>= target_startoffset:  
                                if lang_dic["end_offset"][row2] <= target_endoffset:
                                    if len(target_MWP) > len(lang_dic["target_word"][row2]):
                                        print(lang_dic["target_word"][row2], lang_dic["gold_label"][row2])
                                        target_SW_counter += 1
                                        if lang_dic["gold_label"][row2] != target_GL:
                                            target_irregSW_counter += 1

                # update irreuglar labels counter
                if target_irregSW_counter > 0:
                    irregSW_counter += 1
                    print("Irregular SWs:", target_irregSW_counter,"/",target_SW_counter)
                    if target_SW_counter == target_irregSW_counter:
                        allirregSW_counter += 1
                        print("-- All irregular SWs:")
                    

        # print summary
        print("\nTotal MWPs with at least", min_length,"words:",MWP_counter)
        print("Total complex MWPss:", CMWP_counter)
        print("Total non-complex multiword phrases:", MWP_counter - CMWP_counter)
        print("Total MWPs with at least one opposite label SW:", irregSW_counter)
        print("Total MWPs with all opposite label SWs:", allirregSW_counter)

# %%
MWP_SW_printer("french", 4)
# Out:
# french MWPs with min number of words 4 :
# -
# --------------------
# crise des marchés du crédit 1
# crise 0
# marchés 0
# crédit 0
# Irregular SWs: 3 / 3
# -- All irregular SWs:
# --------------------
# campagne de récolte de fonds 1
# campagne 0
# récolte 0
# fonds 0
# Irregular SWs: 3 / 3
# -- All irregular SWs:
# --------------------
# marque néanmoins sa désapprobation 1
# marque 0
# néanmoins sa désapprobation 1
# désapprobation 1
# Irregular SWs: 1 / 3
# --------------------
# un alcaloïde bi - indolé 1
# Bugey 0
# Irregular SWs: 2 / 2
# -- All irregular SWs:
# --------------------
# Il noue avec lui 1
# noue 1
# --------------------
# les Arawaks et les Caraïbes 1
# les Arawaks 1
# Arawaks 1
# Caraïbes 0
# Irregular SWs: 1 / 3
# --------------------
# grande plantation de sucre 1
# grande 0
# grande plantation 1
# plantation 1
# sucre 0
# Irregular SWs: 2 / 4
# --------------------
# Pétrole et gaz arabes 1
# Pétrole 0
# gaz 0
# arabes 0
# Irregular SWs: 3 / 3
# -- All irregular SWs:
# --------------------
# oxygène et le dioxyde de carbone 1
# oxygène 1
# dioxyde 0
# dioxyde de carbone 1
# carbone 0
# Irregular SWs: 2 / 4
# --------------------
# une seule suivant le courant principal 1
# courant 0
# principal 0
# Irregular SWs: 2 / 2
# -- All irregular SWs:
# --------------------
# Une ceinture de hauts sommets 1
# ceinture 0
# ceinture de hauts sommets 1
# hauts 0
# hauts sommets 1
# sommets 0
# Irregular SWs: 3 / 5
# --------------------
# ceinture de hauts sommets 1
# ceinture 0
# hauts 0
# hauts sommets 1
# sommets 0
# Irregular SWs: 3 / 4
# --------------------
# ligne de partage des eaux 1
# ligne 0
# ligne de partage 1
# partage 0
# partage des eaux 1
# eaux 0
# Irregular SWs: 3 / 5
# --------------------
# cavalerie , ailes , infanterie , cohortes 1
# cavalerie 0
# ailes 0
# infanterie 1
# cohortes 1
# Irregular SWs: 2 / 4
# --------------------
# privilégie la présence de 1
# privilégie 1
# présence 0
# Irregular SWs: 1 / 2
# --------------------
# privilégie la présence de tissu animal 1
# privilégie 1
# privilégie la présence de 1
# présence 0
# tissu 0
# tissu animal 1
# animal 0
# Irregular SWs: 3 / 6
# --------------------
# un circuit électrique fermé constitué de métaux 1
# circuit 0
# circuit électrique fermé 1
# circuit électrique fermé constitué de métaux 1
# électrique 0
# fermé 0
# constitué 0
# constitué de métaux 1
# métaux 0
# Irregular SWs: 5 / 8
# --------------------
# circuit électrique fermé constitué de métaux 1
# circuit 0
# circuit électrique fermé 1
# électrique 0
# fermé 0
# constitué 0
# constitué de métaux 1
# métaux 0
# Irregular SWs: 5 / 7
# --------------------
# un « goût » électrique 1
# goût 1
# électrique 0
# Irregular SWs: 1 / 2
# --------------------
# motif répété de cellules 1
# motif 0
# répété 0
# cellules 1
# Irregular SWs: 2 / 3
# --------------------
# élaborer une pile métallique 1
# élaborer 0
# une pile métallique 1
# pile 0
# pile métallique 1
# métallique 0
# Irregular SWs: 3 / 5
# --------------------
# version artificielle de la raie 1
# version 0
# version artificielle 1
# artificielle 1
# raie 1
# Irregular SWs: 1 / 4
# --------------------
# à la suite de 1
# suite 0
# Irregular SWs: 1 / 1
# -- All irregular SWs:
# --------------------
# coopératives de services préhospitaliers 1
# coopératives 1
# services 0
# préhospitaliers 1
# Irregular SWs: 1 / 3
# --------------------
# Salbutamol , Épinephrine et Glucagon 1
# Salbutamol 1
# Épinephrine 1
# Glucagon 1
# --------------------
# défibrillateur semi - automatique 1
# défibrillateur 0
# semi 0
# automatique 0
# Irregular SWs: 3 / 3
# -- All irregular SWs:
# --------------------
# Églises luthériennes et reformées 1
# Églises 0
# luthériennes 1
# luthériennes et reformées 1
# reformées 0
# Irregular SWs: 2 / 4
#
# Total MWPs with at least 4 words: 51
# Total complex MWPss: 51
# Total non-complex multiword phrases: 0
# Total MWPs with at least one opposite label SW: 45
# Total MWPs with all opposite label SWs: 11

# %%
MWP_SW_printer("english", 5)
# Out:
# english MWPs with min number of words 5 :
# -
# --------------------
# exposure to the property sector 1
# exposure 1
# property sector 1
# sector 1
# property 0
# Irregular SWs: 1 / 4
# --------------------
# lost track of the days 0
# lost track 1
# lost 0
# track 0
# days 0
# Irregular SWs: 1 / 4
# --------------------
# dispute over censorship and security 0
# dispute 1
# censorship 1
# security 1
# Irregular SWs: 3 / 3
# -- All irregular SWs:
# --------------------
# vulnerable to a resilient insurgency 0
# vulnerable 1
# resilient 1
# resilient insurgency 1
# insurgency 1
# Irregular SWs: 4 / 4
# -- All irregular SWs:
# --------------------
# ambulance in a police car 0
# ambulance 1
# police 0
# car 0
# Irregular SWs: 1 / 3
# --------------------
# scheduled to end combat operations 0
# scheduled 1
# combat 1
# end 0
# combat operations 1
# operations 0
# Irregular SWs: 3 / 5
# --------------------
# The Syrian Observatory for Human Rights 1
# Observatory 1
# Syrian 0
# Human 0
# Rights 0
# Irregular SWs: 3 / 4
# --------------------
# blames the bloodshed on armed gangs 0
# blames 1
# bloodshed 1
# armed 0
# gangs 0
# Irregular SWs: 2 / 4
# --------------------
# violence further undermines a U.N.-backed 0
# violence 1
# undermines 1
# Irregular SWs: 2 / 2
# -- All irregular SWs:
# --------------------
# gravity of the economic situation 0
# gravity 1
# economic 0
# economic situation 1
# situation 0
# Irregular SWs: 2 / 4
# --------------------
# refinance as much of the debt 0
# refinance 1
# debt 1
# Irregular SWs: 2 / 2
# -- All irregular SWs:
# --------------------
# taking on ourselves bringing perfection to 0
# bringing perfection 1
# taking 0
# perfection 1
# bringing 0
# Irregular SWs: 2 / 4
# --------------------
# in connection with the incident 0
# in connection with 1
# connection 1
# incident 1
# Irregular SWs: 3 / 3
# -- All irregular SWs:
# --------------------
# questioned on suspicion of assisting 1
# questioned 1
# suspicion 1
# assisting 1
# --------------------
# suspicion of assisting an offender 1
# suspicion 1
# assisting 1
# assisting an offender 1
# offender 1
# --------------------
# new euro zone debt crisis 1
# euro zone 1
# euro zone debt crisis 1
# debt crisis 1
# euro 0
# zone 0
# crisis 1
# debt 0
# Irregular SWs: 3 / 7
# --------------------
# the hole is even bigger 0
# hole 0
# bigger 0
# --------------------
# Successive waves of bank sector clean-ups 1
# Successive 1
# Successive waves 1
# waves 1
# bank sector 1
# sector 1
# bank 0
# clean-ups 1
# Irregular SWs: 1 / 7
# --------------------
# place toxic real estate assets 0
# toxic 1
# place 0
# toxic real estate assets 1
# real estate assets 1
# assets 1
# real 0
# estate 0
# Irregular SWs: 4 / 7
# --------------------
# suspicion of assisting an offender 0
# suspicion 1
# suspicion of assisting 1
# assisting 1
# assisting an offender 0
# Irregular SWs: 3 / 5
# --------------------
# turning a gun on herself 1
# turning 0
# gun 0
# Irregular SWs: 2 / 2
# -- All irregular SWs:
# --------------------
# fallout of a property crash 0
# fallout 1
# property 0
# property crash 1
# crash 1
# Irregular SWs: 3 / 4
# --------------------
# suspicion of assisting an offender 1
# suspicion 1
# assisting 1
# assisting an offender 1
# offender 1
# --------------------
# Successive waves of bank sector clean-ups 1
# Successive 1
# Successive waves 1
# waves 1
# bank sector 1
# bank sector clean-ups 1
# sector 1
# bank 0
# clean-ups 1
# Irregular SWs: 1 / 8
# --------------------
# yields on benchmark Spanish bonds 1
# yields 1
# yields on benchmark 1
# benchmark 1
# benchmark Spanish bonds 1
# Spanish 0
# bonds 0
# Irregular SWs: 2 / 6
# --------------------
# a rising tide of discontent 1
# rising tide 1
# rising tide of discontent 1
# tide 1
# rising 0
# tide of discontent 1
# discontent 1
# Irregular SWs: 1 / 6
# --------------------
# who is MP for the area 0
# MP 0
# area 0
# --------------------
# that of the wider community 0
# --------------------
# Lauren dived in to save her 0
# dived 1
# Lauren 0
# dived in 1
# save 0
# Irregular SWs: 2 / 4
# --------------------
# anti-monopoly bureau leapt into action 0
# anti-monopoly 1
# anti-monopoly bureau 1
# anti-monopoly bureau leapt 0
# bureau 1
# bureau leapt 0
# leapt 1
# action 0
# Irregular SWs: 4 / 7
# --------------------
# Issued twice a year to Congress 1
# Issued 1
# Congress 1
# year 0
# Irregular SWs: 1 / 3
# --------------------
# Military Intelligence and pro-Assad militia 1
# Intelligence 1
# Military 0
# pro-Assad 0
# militia 0
# Irregular SWs: 3 / 4
# --------------------
# tensions resonate in neighboring states 0
# tensions 1
# tensions resonate 1
# resonate 1
# neighboring 1
# states 0
# Irregular SWs: 4 / 5
# --------------------
# Serious Crime Suite at Antrim police station 0
# Serious Crime Suite 1
# Crime Suite 1
# Serious 0
# Suite 1
# Crime 0
# Antrim 1
# police 0
# station 0
# Irregular SWs: 4 / 8
# --------------------
# harvesting of endangered marine species 0
# harvesting 1
# endangered 1
# endangered marine species 1
# marine 1
# species 1
# Irregular SWs: 5 / 5
# -- All irregular SWs:
# --------------------
# unsubtle show of the power 0
# unsubtle 1
# unsubtle show 1
# show 0
# power 0
# Irregular SWs: 2 / 4
# --------------------
# see the light of a new day on the horizon 0
# horizon 1
# light 0
# day 0
# Irregular SWs: 1 / 3
# --------------------
# contents of this illegitimate document 0
# contents 1
# illegitimate 1
# illegitimate document 1
# document 0
# Irregular SWs: 3 / 4
# --------------------
# invading forces and their puppets 0
# invading 1
# invading forces 1
# puppets 1
# forces 0
# Irregular SWs: 3 / 4
# --------------------
# the necessary adjustment of bank balance sheets 0
# necessary adjustment 1
# adjustment 1
# adjustment of bank balance sheets 1
# bank balance sheets 1
# balance sheets 0
# bank 0
# balance 0
# sheets 0
# Irregular SWs: 4 / 8
# --------------------
# adjustment of bank balance sheets 1
# adjustment 1
# bank balance sheets 1
# balance sheets 0
# bank 0
# balance 0
# sheets 0
# Irregular SWs: 4 / 6
# Vestmanlands 0
# Läns 0
# Tidning 0
# VLT 0
# Irregular SWs: 7 / 7
# -- All irregular SWs:
# --------------------
# PIJ in the West Bank 0
# PIJ 0
# West 0
# Bank 0
# --------------------
# Al-Qaeda in the Islamic Maghreb 1
# Al-Qaeda 0
# Maghreb 1
# Islamic 0
# Irregular SWs: 2 / 3
# --------------------
# prioritize prevention rather than repression 0
# prioritize 1
# prioritize prevention 1
# prevention 1
# repression 1
# Irregular SWs: 4 / 4
# -- All irregular SWs:
# --------------------
# as an act of force 0
# act 0
# force 0
# --------------------
# a proportional show of force 1
# proportional 1
# proportional show 0
# proportional show of force 0
# show 0
# force 0
# Irregular SWs: 4 / 5
# --------------------
# wing known as a flaperon 0
# wing 1
# flaperon 1
# Irregular SWs: 2 / 2
# -- All irregular SWs:
# --------------------
# report is known to contain 0
# report 0
# --------------------
# instead of listening to their demands 0
# listening 0
# demands 0
# --------------------
# widespread do you think this phenomenon 0
# widespread 1
# phenomenon 1
# Irregular SWs: 2 / 2
# -- All irregular SWs:
# --------------------
# evidence in honey bees and bumble-bees as well 0
# evidence 1
# bumble-bees 1
# honey 0
# bees 0
# Irregular SWs: 2 / 4
# --------------------
# a lion of American history 1
# lion 0
# American 0
# history 0
# Irregular SWs: 3 / 3
# -- All irregular SWs:
# --------------------
# how the accused might structure their defences 0
# accused 1
# structure 1
# defences 1
# Irregular SWs: 3 / 3
# -- All irregular SWs:
# --------------------
# growing the size of government 1
# growing 0
# government 1
# size 0
# Irregular SWs: 2 / 3
# --------------------
# Polish Prime Minister Beata Szydło 0
# Polish 0
# Prime 0
# Minister 0
# Beata 0
# Szydło 0
# --------------------
# The Social and Popular Assembly 0
# Social 1
# Assembly 1
# Popular 0
# Irregular SWs: 2 / 3
# --------------------
# Meghalaya chief minister V. Shanmuganathan 0
# Meghalaya 1
# minister 1
# chief 0
# Shanmuganathan 1
# Irregular SWs: 3 / 4
# --------------------
# commissioner of the Internal Revenue Service 1
# commissioner 1
# Internal Revenue Service 1
# Internal 0
# Revenue 1
# Service 0
# Irregular SWs: 2 / 5
# --------------------
# U.S. Code of Federal Regulations 1
# Federal 1
# Code 0
# Federal Regulations 1
# Regulations 1
# Irregular SWs: 1 / 4
# --------------------
# advance one candidate over another 0
# advance 1
# candidate 1
# Irregular SWs: 2 / 2
# -- All irregular SWs:
# --------------------
# reinstatement of the military draft 1
# reinstatement 1
# draft 1
# military 0
# Irregular SWs: 1 / 3
# --------------------
# U.S. Commissioner of Internal Revenue 1
# Commissioner 0
# Commissioner of Internal Revenue 0
# Internal Revenue 0
# Internal 0
# Revenue 1
# Irregular SWs: 4 / 5
# --------------------
# emission of light of a certain wave-length 0
# emission 1
# wave-length 1
# light 0
# Irregular SWs: 2 / 3
# --------------------
# plated them out on petridishes 0
# plated 1
# petridishes 1
# Irregular SWs: 2 / 2
# -- All irregular SWs:
# --------------------
# Indian Institute of Management Shillong 1
# Indian 0
# Institute 0
# Institute of Management 1
# Institute of Management Shillong 0
# Management 0
# Shillong 0
